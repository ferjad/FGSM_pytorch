# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms
import numpy
import matplotlib.pyplot as plt
import random
import pickle

# %%
train_dataset=datasets.MNIST(root='./data',
                            train=True,
                            download=True,
                            transform=transforms.ToTensor())
test_dataset=datasets.MNIST(root='./data',
                          train=False,
                          download=True,
                          transform=transforms.ToTensor())
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
batch_size=100
n_iters=3000
num_epochs=int(n_iters*batch_size/len(train_dataset))
train_loader=torch.utils.data.DataLoader(dataset=train_dataset,
                                        batch_size=batch_size,
                                        shuffle=True)
test_loader=torch.utils.data.DataLoader(dataset=test_dataset,
                                       batch_size=batch_size,
                                       shuffle=False)

# %%
class FeedForwardNN(nn.Module):
    def __init__(self,input_size,hidden_size,num_classes):
        super(FeedForwardNN,self).__init__()
        self.fc1=nn.Linear(input_size,hidden_size)
        self.relu=nn.ReLU()
        self.fc2=nn.Linear(hidden_size,num_classes)
        
    def forward(self,x):
        out=self.fc1(x)
        out=self.relu(out)
        out=self.fc2(out)
        return out

# %%
input_size=28*28
hidden_size=512
num_classes=10
learning_rate=0.01
model=FeedForwardNN(input_size,hidden_size,num_classes)
criterion=nn.CrossEntropyLoss()
optimizer=torch.optim.SGD(model.parameters(),lr=learning_rate)

# %%
device=('cuda:0' if torch.cuda.is_available() else 'cpu')
print(device)
model.to(device)
# Out:
# cuda:0
# FeedForwardNN(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
iter=0
for epoch in range(num_epochs):
    for i,(images,labels) in enumerate(train_loader):
        images, labels=images.to(device),labels.to(device)
        images=images.view(-1,28*28)
        optimizer.zero_grad()
        outputs=model(images)
        loss=criterion(outputs,labels)
        loss.backward()
        optimizer.step()
        iter+=1
        if iter % 500 ==0:
            correct=0
            total=0
            for images,labels in test_loader:
                images,labels=images.to(device), labels.to(device)
                images=images.view(-1,28*28)
                outputs=model(images)
                _,predictions=torch.max(outputs,1)
                total+=images.size()[0]
                correct+=(predictions==labels).sum()
                accuracy=float(100*correct)/total
                
                
            print('Loss ', loss.item(), 'Iteration ',
                  iter, ' Accuracy ', accuracy)
# Out:
# Loss  0.962497889995575 Iteration  500  Accuracy  82.67
# Loss  0.6517258286476135 Iteration  1000  Accuracy  87.21

# %%
images_all=list()
adv_all=list()
correct=0
total=0
for images,labels in test_loader:
    images, labels=images.to(device),labels.to(device)
    images=images.view(-1,28*28)
    images.requires_grad_()
    optimizer.zero_grad()
    outputs=model(images)
    loss=criterion(outputs,labels)
    
    
    loss.backward()
    _,predictions=torch.max(outputs,1)
    #FGSM
    epsilon=0.1
    x_grad=torch.sign(images.grad)
    x_adversarial=torch.clamp(images.detach()+epsilon*x_grad,0,1)
    
    _,adversarial_pred=torch.max(model(x_adversarial),1)
    images_all.append([images.view(-1,28,28).detach().cpu().numpy(),labels])
    adv_all.append([x_adversarial.view(-1,28,28).cpu().numpy(),adversarial_pred])

    correct+=(predictions==adversarial_pred).sum()
    total+=len(predictions)
print("Error Rate is ",float(total-correct)*100/total)
# Out:
# Error Rate is  88.82

# %%
curr,label=images_all[0]
currad,labelad=adv_all[0]
print(type(curr),type(label))
# Out:
# <class 'numpy.ndarray'> <class 'torch.Tensor'>

# %%
for a in range(100):
    plt.figure()
    plt.subplot(121)
    plt.imshow(curr[a],cmap='gray')
    plt.subplot(122)
    plt.imshow(currad[a],cmap='gray')
    print("Original Label ", label[a].cpu().numpy(), " Adv Label ",labelad[a].cpu().numpy())
    plt.show()
total=batch_size
correct=(label==labelad).sum()
print("Batch Error rate ",float(total-correct)*100/total)
# Out:
# Original Label  7  Adv Label  7
# Original Label  2  Adv Label  6
# Original Label  1  Adv Label  1
# Original Label  0  Adv Label  0
# Original Label  4  Adv Label  9
# Original Label  1  Adv Label  1
# Original Label  4  Adv Label  8
# Original Label  9  Adv Label  4
# Original Label  5  Adv Label  6
# Original Label  9  Adv Label  7
# Original Label  0  Adv Label  0
# Original Label  6  Adv Label  8
# Original Label  9  Adv Label  4
# Original Label  0  Adv Label  0
# Original Label  1  Adv Label  1
# Original Label  5  Adv Label  3
# Original Label  9  Adv Label  4
# Original Label  7  Adv Label  7
# Original Label  3  Adv Label  6
# Original Label  4  Adv Label  4
# Original Label  9  Adv Label  7
# Original Label  6  Adv Label  5
# Original Label  6  Adv Label  4
# Original Label  5  Adv Label  5
# Original Label  4  Adv Label  7
# Original Label  0  Adv Label  0
# Original Label  7  Adv Label  7
# Original Label  4  Adv Label  4
# Original Label  0  Adv Label  0
# Original Label  1  Adv Label  5
# Original Label  3  Adv Label  3
# Original Label  1  Adv Label  3
# Original Label  3  Adv Label  5
# Original Label  4  Adv Label  0
# Original Label  7  Adv Label  7
# Original Label  2  Adv Label  2
# Original Label  7  Adv Label  7
# Original Label  1  Adv Label  1
# Original Label  2  Adv Label  3
# Original Label  1  Adv Label  8
# Original Label  1  Adv Label  3
# Original Label  7  Adv Label  9
# Original Label  4  Adv Label  9
# Original Label  2  Adv Label  8
# Original Label  3  Adv Label  5
# Original Label  5  Adv Label  3
# Original Label  1  Adv Label  3
# Original Label  2  Adv Label  4
# Original Label  4  Adv Label  9
# Original Label  4  Adv Label  4
# Original Label  6  Adv Label  6
# Original Label  3  Adv Label  5
# Original Label  5  Adv Label  5
# Original Label  5  Adv Label  3
# Original Label  6  Adv Label  2
# Original Label  0  Adv Label  5
# Original Label  4  Adv Label  4
# Original Label  1  Adv Label  3
# Original Label  9  Adv Label  9
# Original Label  5  Adv Label  7
# Original Label  7  Adv Label  7
# Original Label  8  Adv Label  2
# Original Label  9  Adv Label  4
# Original Label  3  Adv Label  2
# Original Label  7  Adv Label  2
# Original Label  4  Adv Label  3
# Original Label  6  Adv Label  2
# Original Label  4  Adv Label  4
# Original Label  3  Adv Label  3
# Original Label  0  Adv Label  0
# Original Label  7  Adv Label  7
# Original Label  0  Adv Label  0
# Original Label  2  Adv Label  0
# Original Label  9  Adv Label  7
# Original Label  1  Adv Label  8
# Original Label  7  Adv Label  4
# Original Label  3  Adv Label  5
# Original Label  2  Adv Label  7
# Original Label  9  Adv Label  8
# Original Label  7  Adv Label  7
# Original Label  7  Adv Label  9
# Original Label  6  Adv Label  2
# Original Label  2  Adv Label  2
# Original Label  7  Adv Label  9
# Original Label  8  Adv Label  5
# Original Label  4  Adv Label  4
# Original Label  7  Adv Label  7
# Original Label  3  Adv Label  5
# Original Label  6  Adv Label  6
# Original Label  1  Adv Label  1
# Original Label  3  Adv Label  3
# Original Label  6  Adv Label  6
# Original Label  9  Adv Label  4
# Original Label  3  Adv Label  3
# Original Label  1  Adv Label  8
# Original Label  4  Adv Label  4
# Original Label  1  Adv Label  3
# Original Label  7  Adv Label  8
# Original Label  6  Adv Label  0
# Original Label  9  Adv Label  9
# Batch Error rate  59.0
